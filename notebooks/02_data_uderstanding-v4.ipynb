# %% [markdown]
# ## Entendimento dos Dados (Data Understanding)
#
# `Coleta inicial dos dados, familiarização com eles, identificação de problemas de qualidade, e geração de hipóteses iniciais.`

# %% [markdown]
# ### Dados Abertos

# %% [markdown]
# Como fontes e dados possíveis, temos:
#
# * Dados abertos da PGFN, disponíveis em <https://www.gov.br/pgfn/pt-br/assuntos/divida-ativa-da-uniao/transparencia-fiscal-1/dados-abertos>
# * Dados abertos da Receita (base CNPJ), disponíveis em <https://dados.gov.br/dados/conjuntos-dados/cadastro-nacional-da-pessoa-juridica---cnpj>
#
# #### PGFN
#
# * **FGTS:** Refere-se a débitos de empregadores com o fundo de garantia.
# * **PREV (Previdenciário):** Débitos de contribuições previdenciárias.
# * **SIDA:** Conjunto de dados do sistema unificado da administração federal, com dados detalhados sobre devedores e sua situação perante a União.
#
# Layout dos arquivos:
#
# ➜ FGTS PREV e SIDA
# | Campo                     | Descrição                                                                 |
# |---------------------------|---------------------------------------------------------------------------|
# | CPF_CNPJ                  | CPF ou CNPJ do devedor inscrito na dívida ativa.                         |
# | TIPO_PESSOA               | Indica se o devedor é pessoa física (F) ou jurídica (J).                 |
# | TIPO_DEVEDOR              | Categoria do devedor: contribuinte individual, empresa, órgão público etc. |
# | NOME_DEVEDOR              | Nome ou razão social do devedor.                                         |
# | UF_DEVEDOR                | Unidade da Federação (estado) do devedor.                               |
# | UNIDADE_RESPONSAVEL       | Unidade da PGFN responsável pela inscrição da dívida.                   |
# | NUMERO_INSCRICAO          | Número único da inscrição da dívida ativa.                              |
# | TIPO_SITUACAO_INSCRICAO   | Tipo da situação da inscrição: ativa, suspensa, extinta etc.            |
# | SITUACAO_INSCRICAO        | Descrição detalhada da situação atual da dívida.                        |
# | TIPO_CREDITO              | Tipo de crédito tributário ou não tributário (ex: FGTS, Multas).        |
# | DATA_INSCRICAO            | Data da inscrição na dívida ativa.                                      |
# | INDICADOR_AJUIZADO        | Indica se a dívida foi ajuizada: 'S' ou 'N'.                            |
# | VALOR_CONSOLIDADO         | Valor total da dívida com acréscimos legais.                            |
#
# ➜ FGTS
# | Campo                  | Descrição                                           |
# |------------------------|---------------------------------------------------|
# | ENTIDADE_RESPONSAVEL   | Entidade que gerou a inscrição do débito FGTS.    |
# | UNIDADE_INSCRICAO      | Unidade/agência que realizou a inscrição do débito FGTS. |
#
#
#
# #### CNPJ (Receita)
#
# **ideias:**
# UF_DEVEDOR: tentar análise geográfica, indicando que alguns estados têm mais devedores. baixar dados do IBGE
# UNIDADE_RESPONSAVEL: tentar analisar a carga de dívidas por unidade da PGFN.
# SITUACAO_INSCRICAO: será que o status da dívida e como isso impacta a cobrança ou ajuizamento.
# TIPO_CREDITO: tentar ver risco associado a diferentes tipos de crédito.
#
# Tentar juntar com CNAE

# %% [markdown]
# ### Exploratory

# %%
import sys
import os

import networkx as nx
from collections import Counter
from networkx.drawing.nx_agraph import graphviz_layout

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from modules.utils.file import (
        find_zip_files_by_pattern,
        read_zip_csvs_as_df,
        save_parquet
)

from modules.utils.dataframe import (
    dataframe_info
)

from modules.utils.plot.style import ( 
    set_plot_style,
)

from modules.utils.plot.save import ( 
    save_figure
)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.float_format = '{:,.2f}'.format
set_plot_style()
os.makedirs('reports/figures', exist_ok=True)

# data_root = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))
data_root = '/home/nicolas/Documents/dados/pgfn/'

# %% [markdown]
# #### Load Data

# %%
zip_files = find_zip_files_by_pattern(directory=f"{data_root}/dados/", pattern='FGTS.zip')
all_dfs = []

for f in zip_files:
    print(f"Processando arquivo: {f}")
    df = read_zip_csvs_as_df(f, encoding='latin1', verbose=False)
    all_dfs.append(df)

dadosDF = pd.concat(all_dfs, ignore_index=True)
# Out:
# Processando arquivo: /home/nicolas/Documents/dados/pgfn//dados/2020T2_Dados_abertos_FGTS.zip
# Processando arquivo: /home/nicolas/Documents/dados/pgfn//dados/2020T1_Dados_abertos_FGTS.zip

# %%
dadosDF.columns
# Out:
# Index(['CPF_CNPJ', 'TIPO_PESSOA', 'TIPO_DEVEDOR', 'NOME_DEVEDOR',
#        'UF_UNIDADE_RESPONSAVEL', 'UNIDADE_RESPONSAVEL', 'ENTIDADE_RESPONSAVEL',
#        'UNIDADE_INSCRICAO', 'NUMERO_INSCRICAO', 'TIPO_SITUACAO_INSCRICAO',
#        'SITUACAO_INSCRICAO', 'RECEITA_PRINCIPAL', 'DATA_INSCRICAO',
#        'INDICADOR_AJUIZADO', 'VALOR_CONSOLIDADO', '__source_file__'],
#       dtype='object')

# %%
# apenas PJ
dadosDF = dadosDF[dadosDF['TIPO_PESSOA'].str.contains('jur', case=False, na=False)]

# %%
dadosDF['CPF_CNPJ'] = (
    dadosDF['CPF_CNPJ']
    .astype(str)
    .str.replace(r'\D', '', regex=True)
    .where(dadosDF['CPF_CNPJ'].notna())
)
dadosDF['DATA_INSCRICAO'] = pd.to_datetime(dadosDF['DATA_INSCRICAO'], format="%d/%m/%Y", errors='coerce')
dadosDF['ANO_INSCRICAO'] = dadosDF['DATA_INSCRICAO'].dt.year.astype('category')
dadosDF['MES_INSCRICAO'] = dadosDF['DATA_INSCRICAO'].dt.month.astype('category')
dadosDF['ANOMES_REFERENCIA'] = dadosDF['__source_file__'].str.extract(r'_(\d{6})\.csv$').astype('category')

dadosDF['TIPO_PESSOA'] = dadosDF['TIPO_PESSOA'].astype('category')
dadosDF['TIPO_DEVEDOR'] = dadosDF['TIPO_DEVEDOR'].astype('category')
dadosDF['UF_UNIDADE_RESPONSAVEL'] = dadosDF['UF_UNIDADE_RESPONSAVEL'].astype('category')
dadosDF['SITUACAO_INSCRICAO'] = dadosDF['SITUACAO_INSCRICAO'].astype('category')
dadosDF['UNIDADE_RESPONSAVEL'] = dadosDF['UNIDADE_RESPONSAVEL'].astype('category')
dadosDF['ENTIDADE_RESPONSAVEL'] = dadosDF['ENTIDADE_RESPONSAVEL'].astype('category')
dadosDF['UNIDADE_INSCRICAO'] = dadosDF['UNIDADE_INSCRICAO'].astype('category')
dadosDF['TIPO_SITUACAO_INSCRICAO'] = dadosDF['TIPO_SITUACAO_INSCRICAO'].astype('category')
dadosDF['INDICADOR_AJUIZADO'] = dadosDF['INDICADOR_AJUIZADO'].astype('category')
dadosDF['RECEITA_PRINCIPAL'] = dadosDF['RECEITA_PRINCIPAL'].astype('category')

dadosDF['VALOR_CONSOLIDADO'] = dadosDF['VALOR_CONSOLIDADO'].astype(float)

# dataframe_info(dadosDF)
dadosDF
# Out:
#               CPF_CNPJ      TIPO_PESSOA TIPO_DEVEDOR  \
# 0       02045981000119  Pessoa jurídica    Principal
# 1       02214258000116  Pessoa jurídica    Principal
# 2       09577695000143  Pessoa jurídica    Principal
# 3       34706168000139  Pessoa jurídica    Principal
# 4       34706168000139  Pessoa jurídica    Principal
# ...                ...              ...          ...
# 882193  07444090000159  Pessoa jurídica    Principal
# 882194  10775040000169  Pessoa jurídica    Principal
# 882195  10775040000169  Pessoa jurídica    Principal
# 882196  02320284000129  Pessoa jurídica    Principal
# 882197  02320284000129  Pessoa jurídica    Principal
#
#                                         NOME_DEVEDOR UF_UNIDADE_RESPONSAVEL  \
# 0       SANCOL SANEAMENTO CONSTRUCAO E COMERCIO LTDA                     AC
# 1                                       I A DO MONTE                     AC
# 2                               EDNA NOBRE FERNANDES                     AC
# 3         CONSTRUCAO PAVIMENTACAO E TRANSPORTES LTDA                     AC
# 4         CONSTRUCAO PAVIMENTACAO E TRANSPORTES LTDA                     AC
# ...                                              ...                    ...
# 882193                                 GILMAR SOARES                     TO
# 882194            COLEGIO POLIVALENTE DE PALMAS LTDA                     TO
# 882195            COLEGIO POLIVALENTE DE PALMAS LTDA                     TO
# 882196                               R PEREIRA GOMES                     TO
# 882197                               R PEREIRA GOMES                     TO
#
#        UNIDADE_RESPONSAVEL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO  \
# 0                     ACRE                 PGFN              ACRE
# 1                     ACRE                 PGFN              ACRE
# 2                     ACRE                 PGFN              ACRE
# 3                     ACRE                 PGFN              ACRE
# 4                     ACRE                 PGFN              ACRE
# ...                    ...                  ...               ...
# 882193           TOCANTINS                 PGFN         TOCANTINS
# 882194           TOCANTINS                 PGFN         TOCANTINS
# 882195           TOCANTINS                 PGFN         TOCANTINS
# 882196           TOCANTINS                 PGFN         TOCANTINS
# 882197           TOCANTINS                 PGFN         TOCANTINS
#
#        NUMERO_INSCRICAO TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO  \
# 0         FGAC201500072             Em cobrança           INSCRITA
# 1         FGAC201100024             Em cobrança           AJUIZADA
# 2         FGAC201700422             Em cobrança           AJUIZADA
# 3         FGAC201000046             Em cobrança           AJUIZADA
# 4         FGAC201000057             Em cobrança           AJUIZADA
# ...                 ...                     ...                ...
# 882193    FGTO200900147             Em cobrança           AJUIZADA
# 882194    FGTO201100077             Em cobrança           AJUIZADA
# 882195    CSTO201100078             Em cobrança           AJUIZADA
# 882196    FGTO200900185             Em cobrança           AJUIZADA
# 882197    CSTO200900186             Em cobrança           AJUIZADA
#
#                  RECEITA_PRINCIPAL DATA_INSCRICAO INDICADOR_AJUIZADO  \
# 0               Contribuições FGTS     2015-02-24                NAO
# 1               Contribuições FGTS     2011-07-12                SIM
# 2               Contribuições FGTS     2017-12-27                SIM
# 3               Contribuições FGTS     2010-09-30                SIM
# 4               Contribuições FGTS     2010-11-18                SIM
# ...                            ...            ...                ...
# 882193          Contribuições FGTS     2009-08-04                SIM
# 882194          Contribuições FGTS     2011-08-18                SIM
# 882195  Contribuições LC110 (FGTS)     2011-08-18                SIM
# 882196          Contribuições FGTS     2009-10-27                SIM
# 882197  Contribuições LC110 (FGTS)     2009-10-27                SIM
#
#         VALOR_CONSOLIDADO                 __source_file__ ANO_INSCRICAO  \
# 0                3,177.31  arquivo_lai_FGTS_AC_202006.csv          2015
# 1                4,751.29  arquivo_lai_FGTS_AC_202006.csv          2011
# 2               34,386.78  arquivo_lai_FGTS_AC_202006.csv          2017
# 3               23,811.87  arquivo_lai_FGTS_AC_202006.csv          2010
# 4              232,077.56  arquivo_lai_FGTS_AC_202006.csv          2010
# ...                   ...                             ...           ...
# 882193           6,282.46  arquivo_lai_FGTS_TO_202002.csv          2009
# 882194           1,731.59  arquivo_lai_FGTS_TO_202002.csv          2011
# 882195             305.80  arquivo_lai_FGTS_TO_202002.csv          2011
# 882196          11,642.49  arquivo_lai_FGTS_TO_202002.csv          2009
# 882197             316.14  arquivo_lai_FGTS_TO_202002.csv          2009
#
#        MES_INSCRICAO ANOMES_REFERENCIA
# 0                  2            202006
# 1                  7            202006
# 2                 12            202006
# 3                  9            202006
# 4                 11            202006
# ...              ...               ...
# 882193             8            202002
# 882194             8            202002
# 882195             8            202002
# 882196            10            202002
# 882197            10            202002
#
# [877120 rows x 19 columns]

# %%
ignore = ['CPF_CNPJ','NOME_DEVEDOR','NUMERO_INSCRICAO','__source_file__']
dataframe_info(dadosDF, ignore=ignore)
# Out:
# Variáveis categóricas:
# ['TIPO_PESSOA', 'TIPO_DEVEDOR', 'UF_UNIDADE_RESPONSAVEL', 'UNIDADE_RESPONSAVEL', 'ENTIDADE_RESPONSAVEL', 'UNIDADE_INSCRICAO', 'TIPO_SITUACAO_INSCRICAO', 'SITUACAO_INSCRICAO', 'RECEITA_PRINCIPAL', 'INDICADOR_AJUIZADO', 'ANO_INSCRICAO', 'MES_INSCRICAO', 'ANOMES_REFERENCIA']
#
# Número de categorias únicas:
# TIPO_PESSOA                  1
# TIPO_DEVEDOR                 1
# UF_UNIDADE_RESPONSAVEL      27
# UNIDADE_RESPONSAVEL        111
# ENTIDADE_RESPONSAVEL         2
# UNIDADE_INSCRICAO          111
# TIPO_SITUACAO_INSCRICAO      4
# SITUACAO_INSCRICAO          10
# RECEITA_PRINCIPAL            2
# INDICADOR_AJUIZADO           2
# ANO_INSCRICAO               51
# MES_INSCRICAO               12
# ANOMES_REFERENCIA            2
# dtype: int64
#
# >>>>> TIPO_PESSOA <<<<<
# Total de categorias: 1
# TIPO_PESSOA
# Pessoa jurídica    100.0%
# Name: proportion, dtype: object
#
# >>>>> TIPO_DEVEDOR <<<<<
# Total de categorias: 1
# TIPO_DEVEDOR
# Principal    100.0%
# Name: proportion, dtype: object
#
# >>>>> UF_UNIDADE_RESPONSAVEL <<<<<
# Total de categorias: 27
# UF_UNIDADE_RESPONSAVEL
# SP    22.25%
# RJ    13.65%
# MG     11.5%
# RS     8.28%
# PR     6.61%
# BA     3.71%
# SC     3.34%
# PA     3.16%
# PE     3.09%
# GO      2.7%
# DF     2.36%
# CE     2.22%
# ES     2.08%
# MT      1.9%
# MA     1.74%
# MS     1.73%
# RN     1.48%
# AL     1.38%
# PB     1.36%
# AM     1.35%
# SE     1.05%
# PI      0.9%
# AP     0.55%
# TO     0.52%
# RO     0.49%
# AC     0.41%
# RR      0.2%
# Name: proportion, dtype: object
#
# >>>>> UNIDADE_RESPONSAVEL <<<<<
# Total de categorias: 111
# UNIDADE_RESPONSAVEL
# Não se Aplica              37.02%
# 2ª REGIÃO                   5.49%
# 3ª REGIÃO                   4.38%
# MINAS GERAIS                3.96%
# 4ª REGIÃO                   2.22%
#                             ...
# BARREIRAS                   0.03%
# CACHOEIRO DE ITAPEMIRIM      0.0%
# RESENDE                      0.0%
# MOSSORO                      0.0%
# ANGRA DOS REIS               0.0%
# Name: proportion, Length: 111, dtype: object
#
# >>>>> ENTIDADE_RESPONSAVEL <<<<<
# Total de categorias: 2
# ENTIDADE_RESPONSAVEL
# PGFN     62.98%
# CAIXA    37.02%
# Name: proportion, dtype: object
#
# >>>>> UNIDADE_INSCRICAO <<<<<
# Total de categorias: 111
# UNIDADE_INSCRICAO
# 3ª REGIÃO                   8.1%
# 2ª REGIÃO                  7.42%
# MINAS GERAIS               5.93%
# 4ª REGIÃO                  3.66%
# 5ª REGIÃO                  2.94%
#                            ...
# BARREIRAS                  0.03%
# CACHOEIRO DE ITAPEMIRIM    0.03%
# JARAGUA DO SUL             0.02%
# ANGRA DOS REIS             0.01%
# MOSSORO                     0.0%
# Name: proportion, Length: 111, dtype: object
#
# >>>>> TIPO_SITUACAO_INSCRICAO <<<<<
# Total de categorias: 4
# TIPO_SITUACAO_INSCRICAO
# Em cobrança         97.34%
# Benefício Fiscal     2.56%
# Garantia              0.1%
# Não se aplica         0.0%
# Name: proportion, dtype: object
#
# >>>>> SITUACAO_INSCRICAO <<<<<
# Total de categorias: 10
# SITUACAO_INSCRICAO
# AJUIZADA           78.69%
# INSCRITA           17.24%
# AJUIZ PARCELADA      1.7%
# PETICIONADA         1.28%
# INSCR PARCELADA     0.85%
# EMBARGADA            0.2%
# OUTROS INSCRITA     0.02%
# OUTROS AJUIZADA     0.02%
# TRANSFERIDA          0.0%
# ENC PROTESTO         0.0%
# Name: proportion, dtype: object
#
# >>>>> RECEITA_PRINCIPAL <<<<<
# Total de categorias: 2
# RECEITA_PRINCIPAL
# Contribuições FGTS            86.4%
# Contribuições LC110 (FGTS)    13.6%
# Name: proportion, dtype: object
#
# >>>>> INDICADOR_AJUIZADO <<<<<
# Total de categorias: 2
# INDICADOR_AJUIZADO
# SIM    80.61%
# NAO    19.39%
# Name: proportion, dtype: object
#
# >>>>> ANO_INSCRICAO <<<<<
# Total de categorias: 51
# ANO_INSCRICAO
# 2016    8.53%
# 2019    7.13%
# 2017    6.61%
# 1983    6.18%
# 2008    5.68%
# 2015    5.37%
# 2009    4.56%
# 2001    4.32%
# 2000    3.89%
# 2018    3.72%
# 2013    3.66%
# 2011    3.63%
# 2014    3.59%
# 2010    3.59%
# 2012    3.51%
# 2007     3.1%
# 2002    2.97%
# 1998     2.5%
# 1982    2.45%
# 1999    2.33%
# 1997    2.17%
# 1996    1.28%
# 2020    1.28%
# 2003    1.21%
# 1984    0.96%
# 1989    0.79%
# 2005    0.69%
# 2004    0.68%
# 1981    0.67%
# 1985    0.62%
# 2006    0.58%
# 1988    0.35%
# 1980    0.34%
# 1979    0.31%
# 1977     0.2%
# 1987    0.15%
# 1978    0.15%
# 1976     0.1%
# 1986    0.09%
# 1973    0.02%
# 1995    0.01%
# 1971    0.01%
# 1990    0.01%
# 1972    0.01%
# 1974    0.01%
# 1991     0.0%
# 1992     0.0%
# 1975     0.0%
# 1970     0.0%
# 1994     0.0%
# 1993     0.0%
# Name: proportion, dtype: object
#
# >>>>> MES_INSCRICAO <<<<<
# Total de categorias: 12
# MES_INSCRICAO
# 8     11.07%
# 11     9.66%
# 7      9.19%
# 6      9.15%
# 5      8.87%
# 12     8.08%
# 3      7.83%
# 1      7.72%
# 9      7.64%
# 4      7.33%
# 10     7.03%
# 2      6.44%
# Name: proportion, dtype: object
#
# >>>>> ANOMES_REFERENCIA <<<<<
# Total de categorias: 2
# ANOMES_REFERENCIA
# 202002    50.02%
# 202006    49.98%
# Name: proportion, dtype: object
#
# Variáveis numéricas:
# ['VALOR_CONSOLIDADO']
#
# Resumo estatístico:
#        VALOR_CONSOLIDADO
# count         877,120.00
# mean           85,127.56
# std           766,078.18
# min                 0.02
# 25%             2,767.87
# 50%             9,321.92
# 75%            33,811.04
# max       153,093,627.92
#
#
# Informações gerais do DataFrame:
# Uso de memória: 30.98 MB
# Shape: (877120, 19)
# Colunas: ['CPF_CNPJ', 'TIPO_PESSOA', 'TIPO_DEVEDOR', 'NOME_DEVEDOR', 'UF_UNIDADE_RESPONSAVEL', 'UNIDADE_RESPONSAVEL', 'ENTIDADE_RESPONSAVEL', 'UNIDADE_INSCRICAO', 'NUMERO_INSCRICAO', 'TIPO_SITUACAO_INSCRICAO', 'SITUACAO_INSCRICAO', 'RECEITA_PRINCIPAL', 'DATA_INSCRICAO', 'INDICADOR_AJUIZADO', 'VALOR_CONSOLIDADO', '__source_file__', 'ANO_INSCRICAO', 'MES_INSCRICAO', 'ANOMES_REFERENCIA']
#
# Valores ausentes por coluna:
# CPF_CNPJ                        0
# TIPO_PESSOA                     0
# TIPO_DEVEDOR                    0
# NOME_DEVEDOR                    0
# UF_UNIDADE_RESPONSAVEL     324705
# UNIDADE_RESPONSAVEL             0
# ENTIDADE_RESPONSAVEL            0
# UNIDADE_INSCRICAO               0
# NUMERO_INSCRICAO                0
# TIPO_SITUACAO_INSCRICAO         0
# SITUACAO_INSCRICAO              0
# RECEITA_PRINCIPAL               0
# DATA_INSCRICAO                  0
# INDICADOR_AJUIZADO              0
# VALOR_CONSOLIDADO               0
# __source_file__                 0
# ANO_INSCRICAO                   0
# MES_INSCRICAO                   0
# ANOMES_REFERENCIA               0
# dtype: int64
#
# Tamanho total (elementos): 16665280

# %% [markdown]
# ### Make file INSCRICAO_BASE

# %%
filepath = f"{data_root}/data/intermediate/inscricao_base.parquet"
columns = ['NUMERO_INSCRICAO', 'CPF_CNPJ', 'NOME_DEVEDOR', 'DATA_INSCRICAO', 'ANO_INSCRICAO', 'MES_INSCRICAO', 'TIPO_PESSOA', 'TIPO_DEVEDOR', 'UF_UNIDADE_RESPONSAVEL', 'UNIDADE_RESPONSAVEL', 'RECEITA_PRINCIPAL','ENTIDADE_RESPONSAVEL', 'UNIDADE_INSCRICAO']
base = save_parquet(df=dadosDF, path=filepath, columns=columns, unique=True)
# Out:
# File saved at: /home/nicolas/Documents/dados/pgfn//data/intermediate/inscricao_base.parquet

# %%
# df = pd.read_parquet(filepath)
df
# Out:
#        NUMERO_INSCRICAO        CPF_CNPJ  \
# 0         FGAC201500072  02045981000119
# 1         FGAC201100024  02214258000116
# 2         FGAC201700422  09577695000143
# 3         FGAC201000046  34706168000139
# 4         FGAC201000057  34706168000139
# ...                 ...             ...
# 881891    CSTO201800029  03601036000380
# 881894    CSTO201900191  08665816000146
# 881940    FGTO201900074  07062767000194
# 881958    FGTO200900187  09377997000410
# 882117    FGRJ000084468  33639238000110
#
#                                              NOME_DEVEDOR DATA_INSCRICAO  \
# 0            SANCOL SANEAMENTO CONSTRUCAO E COMERCIO LTDA     2015-02-24
# 1                                            I A DO MONTE     2011-07-12
# 2                                    EDNA NOBRE FERNANDES     2017-12-27
# 3              CONSTRUCAO PAVIMENTACAO E TRANSPORTES LTDA     2010-09-30
# 4              CONSTRUCAO PAVIMENTACAO E TRANSPORTES LTDA     2010-11-18
# ...                                                   ...            ...
# 881891                             IPANEMA SEGURANCA LTDA     2018-06-28
# 881894                                   BUENO & CIA LTDA     2019-09-26
# 881940  CENTRO DE FORMACAO DE CONDUTORES DE VEICULOS A...     2019-06-19
# 881958                                        MARGEN S.A.     2009-10-27
# 882117                               R9 CONVENIENCIA LTDA     1983-08-02
#
#        ANO_INSCRICAO MES_INSCRICAO      TIPO_PESSOA TIPO_DEVEDOR  \
# 0               2015             2  Pessoa jurídica    Principal
# 1               2011             7  Pessoa jurídica    Principal
# 2               2017            12  Pessoa jurídica    Principal
# 3               2010             9  Pessoa jurídica    Principal
# 4               2010            11  Pessoa jurídica    Principal
# ...              ...           ...              ...          ...
# 881891          2018             6  Pessoa jurídica    Principal
# 881894          2019             9  Pessoa jurídica    Principal
# 881940          2019             6  Pessoa jurídica    Principal
# 881958          2009            10  Pessoa jurídica    Principal
# 882117          1983             8  Pessoa jurídica    Principal
#
#        UF_UNIDADE_RESPONSAVEL UNIDADE_RESPONSAVEL           RECEITA_PRINCIPAL  \
# 0                          AC                ACRE          Contribuições FGTS
# 1                          AC                ACRE          Contribuições FGTS
# 2                          AC                ACRE          Contribuições FGTS
# 3                          AC                ACRE          Contribuições FGTS
# 4                          AC                ACRE          Contribuições FGTS
# ...                       ...                 ...                         ...
# 881891                     TO           TOCANTINS  Contribuições LC110 (FGTS)
# 881894                     TO           TOCANTINS  Contribuições LC110 (FGTS)
# 881940                     TO           TOCANTINS          Contribuições FGTS
# 881958                     TO           TOCANTINS          Contribuições FGTS
# 882117                     TO           TOCANTINS          Contribuições FGTS
#
#        ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO
# 0                      PGFN              ACRE
# 1                      PGFN              ACRE
# 2                      PGFN              ACRE
# 3                      PGFN              ACRE
# 4                      PGFN              ACRE
# ...                     ...               ...
# 881891                 PGFN         TOCANTINS
# 881894                 PGFN         TOCANTINS
# 881940                 PGFN         TOCANTINS
# 881958                 PGFN         TOCANTINS
# 882117                 PGFN         2ª REGIÃO
#
# [446172 rows x 13 columns]

# %% [markdown]
# ### Make file INSCRICAO_ANOMES

# %%
filepath = f"{data_root}/data/intermediate/inscricao_anomes_valor.parquet"
columns = ['NUMERO_INSCRICAO', 'ANOMES_REFERENCIA', 'VALOR_CONSOLIDADO', 'TIPO_SITUACAO_INSCRICAO', 'SITUACAO_INSCRICAO', 'INDICADOR_AJUIZADO']
order_by = ['NUMERO_INSCRICAO','ANOMES_REFERENCIA']

base_anomes = save_parquet(df=dadosDF, path=filepath, columns=columns, order_by=order_by)
base_anomes
# Out:
# File saved at: /home/nicolas/Documents/dados/pgfn//data/intermediate/inscricao_anomes_valor.parquet
#        NUMERO_INSCRICAO ANOMES_REFERENCIA  VALOR_CONSOLIDADO  \
# 441016    CSAC200700028            202002             204.45
# 374       CSAC200700028            202006             206.32
# 441370    CSAC200700039            202002             331.56
# 339       CSAC200700039            202006             334.70
# 441123    CSAC200700043            202002             362.21
# ...                 ...               ...                ...
# 82467     FGUB000100060            202006          19,895.60
# 517604    FGUB000100069            202002         105,398.99
# 81129     FGUB000100069            202006         106,122.17
# 521562    FGUB000990267            202002           7,657.65
# 74463     FGUB000990267            202006           7,710.17
#
#        TIPO_SITUACAO_INSCRICAO SITUACAO_INSCRICAO INDICADOR_AJUIZADO
# 441016             Em cobrança           AJUIZADA                SIM
# 374                Em cobrança           AJUIZADA                SIM
# 441370             Em cobrança           INSCRITA                NAO
# 339                Em cobrança           INSCRITA                NAO
# 441123             Em cobrança           INSCRITA                NAO
# ...                        ...                ...                ...
# 82467              Em cobrança           AJUIZADA                SIM
# 517604             Em cobrança           AJUIZADA                SIM
# 81129              Em cobrança           AJUIZADA                SIM
# 521562             Em cobrança           AJUIZADA                SIM
# 74463              Em cobrança           AJUIZADA                SIM
#
# [877120 rows x 6 columns]

# %%
#TODO:  Definir faixa

# %% [markdown]
# ### Make file INSCRICAO_HIST_IND_AJUIZAMENTO

# %%
# dadosDF['DATA_INSCRICAO'].hist(bins=5)
df = dadosDF.copy()
df.groupby('NUMERO_INSCRICAO')['INDICADOR_AJUIZADO'].shift()
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 882193    SIM
# 882194    SIM
# 882195    SIM
# 882196    SIM
# 882197    SIM
# Name: INDICADOR_AJUIZADO, Length: 877120, dtype: category
# Categories (2, object): ['NAO', 'SIM']

# %%
# Cópia do dataframe original e preparação
df = dadosDF.copy()
df['ANOMES_REFERENCIA'] = df['ANOMES_REFERENCIA'].astype(int)
df.sort_values(by=['NUMERO_INSCRICAO', 'ANOMES_REFERENCIA'], inplace=True)

# Detecta mudanças de ajuizamento
df['AJUIZADO_SHIFT'] = df.groupby('NUMERO_INSCRICAO')['INDICADOR_AJUIZADO'].shift()
# df['MUDANCA_AJUIZADO'] = (
#     (df['INDICADOR_AJUIZADO'] != df['AJUIZADO_SHIFT']) &
#     (df['AJUIZADO_SHIFT'].notna())
# )
df['MUDANCA_AJUIZADO_N2S'] = (df['INDICADOR_AJUIZADO'] == 'SIM') & (df['AJUIZADO_SHIFT'] == 'NAO')
df['MUDANCA_AJUIZADO_S2N'] = (df['INDICADOR_AJUIZADO'] == 'NAO') & (df['AJUIZADO_SHIFT'] == 'SIM')

# Cria colunas SIT_YYYYMM e MUDOU_YYYYMM
df['ANOMES_REFERENCIA'] = df['ANOMES_REFERENCIA'].astype(str)
df['SIT_COL'] = 'IND_AJUIZ_' + df['ANOMES_REFERENCIA']
df['MUDOU_COL_S2N']  = 'MUDOU_S2N_' + df['ANOMES_REFERENCIA']
df['MUDOU_COL_N2S'] = 'MUDOU_N2S_' + df['ANOMES_REFERENCIA']

# Pivot das situações
df_pivot = df.pivot(index='NUMERO_INSCRICAO', columns='SIT_COL', values='INDICADOR_AJUIZADO').reset_index()

# Pivot das mudanças
df_mudouS2N = df.pivot(index='NUMERO_INSCRICAO', columns='MUDOU_COL_S2N', values='MUDANCA_AJUIZADO_N2S').reset_index()

df_mudouN2S = df.pivot(index='NUMERO_INSCRICAO', columns='MUDOU_COL_N2S', values='MUDANCA_AJUIZADO_S2N').reset_index()

# Junta os dois pivot
hist_mudanca = df_pivot.merge(df_mudouS2N, on='NUMERO_INSCRICAO', how='outer') \
    .merge(df_mudouN2S, on='NUMERO_INSCRICAO', how='outer')


filepath = f"{data_root}/data/intermediate/inscricao_hist_mudanca.parquet"
save_parquet(df=hist_mudanca, path=filepath)

hist_mudanca
# Out:
# File saved at: /home/nicolas/Documents/dados/pgfn//data/intermediate/inscricao_hist_mudanca.parquet
#        NUMERO_INSCRICAO IND_AJUIZ_202002 IND_AJUIZ_202006 MUDOU_S2N_202002  \
# 0         CSAC200700028              SIM              SIM            False
# 1         CSAC200700039              NAO              NAO            False
# 2         CSAC200700043              NAO              NAO            False
# 3         CSAC200700046              SIM              SIM            False
# 4         CSAC200700048              SIM              SIM            False
# ...                 ...              ...              ...              ...
# 442741    FGUB000099128              SIM              SIM            False
# 442742    FGUB000099159              SIM              SIM            False
# 442743    FGUB000100060              SIM              SIM            False
# 442744    FGUB000100069              SIM              SIM            False
# 442745    FGUB000990267              SIM              SIM            False
#
#        MUDOU_S2N_202006 MUDOU_N2S_202002 MUDOU_N2S_202006
# 0                 False            False            False
# 1                 False            False            False
# 2                 False            False            False
# 3                 False            False            False
# 4                 False            False            False
# ...                 ...              ...              ...
# 442741            False            False            False
# 442742            False            False            False
# 442743            False            False            False
# 442744            False            False            False
# 442745            False            False            False
#
# [442746 rows x 7 columns]

# %% [markdown]
# Tem inscricao que estavam como SIM e voltaram para NAO: FGGO201000004

# %%
hist_mudanca[hist_mudanca["MUDOU_S2N_202006"] == True]
# Out:
#        NUMERO_INSCRICAO IND_AJUIZ_202002 IND_AJUIZ_202006 MUDOU_S2N_202002  \
# 236       CSAC201900027              NAO              SIM            False
# 245       CSAC201900062              NAO              SIM            False
# 249       CSAC201900074              NAO              SIM            False
# 250       CSAC201900076              NAO              SIM            False
# 251       CSAC201900079              NAO              SIM            False
# ...                 ...              ...              ...              ...
# 434220    FGTO201900177              NAO              SIM            False
# 434228    FGTO201900187              NAO              SIM            False
# 434230    FGTO201900189              NAO              SIM            False
# 434246    FGTO201900210              NAO              SIM            False
# 439202    FGTSRJ9700050              NAO              SIM            False
#
#        MUDOU_S2N_202006 MUDOU_N2S_202002 MUDOU_N2S_202006
# 236                True            False            False
# 245                True            False            False
# 249                True            False            False
# 250                True            False            False
# 251                True            False            False
# ...                 ...              ...              ...
# 434220             True            False            False
# 434228             True            False            False
# 434230             True            False            False
# 434246             True            False            False
# 439202             True            False            False
#
# [4263 rows x 7 columns]

# %%
inscricoes_target = hist_mudanca[hist_mudanca["MUDOU_S2N_202006"] == True]["NUMERO_INSCRICAO"]
inscricoes_target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10866/3171603386.py in ?()
#       1 inscricoes_target = hist_mudanca[hist_mudanca["MUDOU_N2S_202006"] == True]["NUMERO_INSCRICAO"]
#       2
#       3 filepath = f"{data_root}/data/intermediate/inscricao_targets.parquet"
# ----> 4 save_parquet(df=inscricoes_target, path=filepath)
#       5
#       6 inscricoes_target
#
# ~/GDrive/educacao/00-pos/UNB/20250328_PPCA0027_MDM_T01/01-ppca_mdm_trabalho/ppca_mdm_pgfn_previsao_judicializacao/modules/utils/file.py in ?(df, path, columns, unique, order_by)
#     105     if not path.endswith(".parquet"):
#     106         path += ".parquet"
#     107
#     108     # Save to Parquet
# --> 109     df_filtered.to_parquet(path, index=False)
#     110     print(f"File saved at: {path}")
#     111
#     112     return df_filtered
#
# ~/GDrive/educacao/00-pos/UNB/20250328_PPCA0027_MDM_T01/01-ppca_mdm_trabalho/ppca_mdm_pgfn_previsao_judicializacao/venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_parquet'

# %%
result = base[base["NUMERO_INSCRICAO"].isin(inscricoes_target)].sort_values(
    by=["NUMERO_INSCRICAO"]
)

filepath = f"{data_root}/data/intermediate/inscricao_targets.parquet"
save_parquet(df=result, path=filepath)

result
# Out:
# File saved at: /home/nicolas/Documents/dados/pgfn//data/intermediate/inscricao_targets.parquet
#        NUMERO_INSCRICAO        CPF_CNPJ                        NOME_DEVEDOR  \
# 97279     FGGO201000004  04288310000104                   POSTO DO CEU LTDA
# 321785    FGRJ201801041  35934488000109  USIBRITO COMERCIO E INDUSTRIA LTDA
#
#        DATA_INSCRICAO ANO_INSCRICAO MES_INSCRICAO      TIPO_PESSOA  \
# 97279      2010-01-12          2010             1  Pessoa jurídica
# 321785     2018-08-03          2018             8  Pessoa jurídica
#
#        TIPO_DEVEDOR UF_UNIDADE_RESPONSAVEL UNIDADE_RESPONSAVEL  \
# 97279     Principal                    NaN       Não se Aplica
# 321785    Principal                     RJ           2ª REGIÃO
#
#          RECEITA_PRINCIPAL ENTIDADE_RESPONSAVEL UNIDADE_INSCRICAO
# 97279   Contribuições FGTS                CAIXA             GOIAS
# 321785  Contribuições FGTS                 PGFN         2ª REGIÃO
